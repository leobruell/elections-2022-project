# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as  np
pd.options.display.max_columns = None
# %matplotlib inline
import datetime as dt

# %%
senate_elections = pd.read_csv('1976-2020-senate.csv', encoding = "ISO-8859-1")

# %% [markdown]
# https://github.com/fivethirtyeight/data/tree/master/polls

# %%
senate_elections.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976  ARIZONA       AZ           4         86        61  US SENATE
# 1  1976  ARIZONA       AZ           4         86        61  US SENATE
# 2  1976  ARIZONA       AZ           4         86        61  US SENATE
# 3  1976  ARIZONA       AZ           4         86        61  US SENATE
# 4  1976  ARIZONA       AZ           4         86        61  US SENATE
#
#     district stage  special            candidate party_detailed  writein  \
# 0  statewide   gen    False          SAM STEIGER     REPUBLICAN    False
# 1  statewide   gen    False  WM. MATHEWS FEIGHAN    INDEPENDENT    False
# 2  statewide   gen    False     DENNIS DECONCINI       DEMOCRAT    False
# 3  statewide   gen    False        ALLAN NORWITZ    LIBERTARIAN    False
# 4  statewide   gen    False            BOB FIELD    INDEPENDENT    False
#
#     mode  candidatevotes  totalvotes  unofficial   version party_simplified
# 0  total          321236      741210       False  20210114       REPUBLICAN
# 1  total            1565      741210       False  20210114            OTHER
# 2  total          400334      741210       False  20210114         DEMOCRAT
# 3  total            7310      741210       False  20210114      LIBERTARIAN
# 4  total           10765      741210       False  20210114            OTHER

# %%
# !ls
# Out:
# 1976-2020-senate.csv		     initial-data-explore.ipynb
# cleaned_data			     president_approval_polls.csv
# codebook-us-senate-1976тАУ2020.md    president_approval_polls_historical.csv
# generic_ballot_polls.csv	     README.md
# generic_ballot_polls_historical.csv  senate_polls_historical.csv

# %%
senate_polls = pd.read_csv('senate_polls_historical.csv')

# %%
senate_polls.head(10)
# Out:
#    poll_id  pollster_id          pollster sponsor_ids       sponsors  \
# 0    73993         1528        AtlasIntel         NaN            NaN
# 1    73993         1528        AtlasIntel         NaN            NaN
# 2    73993         1528        AtlasIntel         NaN            NaN
# 3    73993         1528        AtlasIntel         NaN            NaN
# 4    74006         1250   Trafalgar Group         NaN            NaN
# 5    74006         1250   Trafalgar Group         NaN            NaN
# 6    74006         1250   Trafalgar Group         NaN            NaN
# 7    74006         1250   Trafalgar Group         NaN            NaN
# 8    73992          235  InsiderAdvantage         195  Fox 5 Atlanta
# 9    73992          235  InsiderAdvantage         195  Fox 5 Atlanta
#
#        display_name  pollster_rating_id            pollster_rating_name  \
# 0        AtlasIntel               546.0                      AtlasIntel
# 1        AtlasIntel               546.0                      AtlasIntel
# 2        AtlasIntel               546.0                      AtlasIntel
# 3        AtlasIntel               546.0                      AtlasIntel
# 4   Trafalgar Group               338.0                 Trafalgar Group
# 5   Trafalgar Group               338.0                 Trafalgar Group
# 6   Trafalgar Group               338.0                 Trafalgar Group
# 7   Trafalgar Group               338.0                 Trafalgar Group
# 8  InsiderAdvantage               243.0  Opinion Savvy/InsiderAdvantage
# 9  InsiderAdvantage               243.0  Opinion Savvy/InsiderAdvantage
#
#   fte_grade        methodology    state start_date end_date  \
# 0         A  Live Phone/Online  Georgia     1/2/21   1/4/21
# 1         A  Live Phone/Online  Georgia     1/2/21   1/4/21
# 2         A  Live Phone/Online  Georgia     1/2/21   1/4/21
# 3         A  Live Phone/Online  Georgia     1/2/21   1/4/21
# 4        A-    IVR/Online/Text  Georgia     1/2/21   1/4/21
# 5        A-    IVR/Online/Text  Georgia     1/2/21   1/4/21
# 6        A-    IVR/Online/Text  Georgia     1/2/21   1/4/21
# 7        A-    IVR/Online/Text  Georgia     1/2/21   1/4/21
# 8         B     IVR/Live Phone  Georgia     1/3/21   1/3/21
# 9         B     IVR/Live Phone  Georgia     1/3/21   1/3/21
#
#    sponsor_candidate_id sponsor_candidate sponsor_candidate_party  \
# 0                   NaN               NaN                     NaN
# 1                   NaN               NaN                     NaN
# 2                   NaN               NaN                     NaN
# 3                   NaN               NaN                     NaN
# 4                   NaN               NaN                     NaN
# 5                   NaN               NaN                     NaN
# 6                   NaN               NaN                     NaN
# 7                   NaN               NaN                     NaN
# 8                   NaN               NaN                     NaN
# 9                   NaN               NaN                     NaN
#
#    question_id  sample_size population  subpopulation population_full  \
# 0       138823        857.0         lv            NaN              lv
# 1       138823        857.0         lv            NaN              lv
# 2       138824        857.0         lv            NaN              lv
# 3       138824        857.0         lv            NaN              lv
# 4       138845       1056.0         lv            NaN              lv
# 5       138845       1056.0         lv            NaN              lv
# 6       138846       1056.0         lv            NaN              lv
# 7       138846       1056.0         lv            NaN              lv
# 8       138821        500.0         lv            NaN              lv
# 9       138821        500.0         lv            NaN              lv
#
#   tracking    created_at notes  \
# 0      NaN  1/4/21 19:35   NaN
# 1      NaN  1/4/21 19:35   NaN
# 2      NaN  1/4/21 19:35   NaN
# 3      NaN  1/4/21 19:35   NaN
# 4      NaN  1/5/21 09:57   NaN
# 5      NaN  1/5/21 09:57   NaN
# 6      NaN  1/5/21 09:57   NaN
# 7      NaN  1/5/21 09:57   NaN
# 8      NaN  1/4/21 16:12   NaN
# 9      NaN  1/4/21 16:12   NaN
#
#                                                  url source  internal  \
# 0  https://projects.fivethirtyeight.com/polls/202...    538     False
# 1  https://projects.fivethirtyeight.com/polls/202...    538     False
# 2  https://projects.fivethirtyeight.com/polls/202...    538     False
# 3  https://projects.fivethirtyeight.com/polls/202...    538     False
# 4  https://www.thetrafalgargroup.org/news/ga-sen-...    538     False
# 5  https://www.thetrafalgargroup.org/news/ga-sen-...    538     False
# 6  https://www.thetrafalgargroup.org/news/ga-sen-...    538     False
# 7  https://www.thetrafalgargroup.org/news/ga-sen-...    538     False
# 8  https://insideradvantage.com/2021/01/04/breaki...    538     False
# 9  https://insideradvantage.com/2021/01/04/breaki...    538     False
#
#   partisan  race_id  cycle  office_type  seat_number  seat_name election_date  \
# 0      NaN     8737   2020  U.S. Senate            0   Class II        1/5/21
# 1      NaN     8737   2020  U.S. Senate            0   Class II        1/5/21
# 2      NaN     7781   2020  U.S. Senate            2  Class III        1/5/21
# 3      NaN     7781   2020  U.S. Senate            2  Class III        1/5/21
# 4      REP     8737   2020  U.S. Senate            0   Class II        1/5/21
# 5      REP     8737   2020  U.S. Senate            0   Class II        1/5/21
# 6      REP     7781   2020  U.S. Senate            2  Class III        1/5/21
# 7      REP     7781   2020  U.S. Senate            2  Class III        1/5/21
# 8      NaN     8737   2020  U.S. Senate            0   Class II        1/5/21
# 9      NaN     8737   2020  U.S. Senate            0   Class II        1/5/21
#
#     stage  nationwide_batch  ranked_choice_reallocated party    answer  \
# 0  runoff             False                      False   DEM    Ossoff
# 1  runoff             False                      False   REP    Perdue
# 2  runoff             False                      False   DEM   Warnock
# 3  runoff             False                      False   REP  Loeffler
# 4  runoff             False                      False   DEM    Ossoff
# 5  runoff             False                      False   REP    Perdue
# 6  runoff             False                      False   DEM   Warnock
# 7  runoff             False                      False   REP  Loeffler
# 8  runoff             False                      False   DEM    Ossoff
# 9  runoff             False                      False   REP    Perdue
#
#    candidate_id   candidate_name   pct
# 0         14567       Jon Ossoff  51.3
# 1         14568  David A. Perdue  46.8
# 2         14489  Raphael Warnock  50.8
# 3         13671   Kelly Loeffler  46.9
# 4         14567       Jon Ossoff  49.4
# 5         14568  David A. Perdue  48.5
# 6         14489  Raphael Warnock  48.4
# 7         13671   Kelly Loeffler  49.7
# 8         14567       Jon Ossoff  48.6
# 9         14568  David A. Perdue  48.7

# %%
senate_polls.shape
# Out:
# (4593, 42)

# %%
# !ls
# Out:
# 1976-2020-senate.csv		     initial-data-explore.ipynb
# cleaned_data			     president_approval_polls.csv
# codebook-us-senate-1976тАУ2020.md    president_approval_polls_historical.csv
# generic_ballot_polls.csv	     README.md
# generic_ballot_polls_historical.csv  senate_polls_historical.csv

# %%
gen_ballot = pd.read_csv('generic_ballot_polls_historical.csv')

# %%
gen_ballot['end_date'] = pd.to_datetime(gen_ballot['end_date'])
gen_ballot['start_date'] = pd.to_datetime(gen_ballot['start_date'])

# %%
gen_ballot['cycle'].value_counts()
# Out:
# 2018    1790
# 2020     943
# Name: cycle, dtype: int64

# %%
gen_ballot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2733 entries, 0 to 2732
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   poll_id                  2733 non-null   int64
#  1   pollster_id              2733 non-null   int64
#  2   pollster                 2733 non-null   object
#  3   sponsor_ids              2200 non-null   object
#  4   sponsors                 2200 non-null   object
#  5   display_name             2733 non-null   object
#  6   pollster_rating_id       2733 non-null   int64
#  7   pollster_rating_name     2733 non-null   object
#  8   fte_grade                2715 non-null   object
#  9   methodology              2671 non-null   object
#  10  state                    0 non-null      float64
#  11  start_date               2733 non-null   datetime64[ns]
#  12  end_date                 2733 non-null   datetime64[ns]
#  13  sponsor_candidate_id     0 non-null      float64
#  14  sponsor_candidate        0 non-null      float64
#  15  sponsor_candidate_party  0 non-null      float64
#  16  question_id              2733 non-null   int64
#  17  sample_size              2732 non-null   float64
#  18  population               2733 non-null   object
#  19  subpopulation            0 non-null      float64
#  20  population_full          2733 non-null   object
#  21  tracking                 1955 non-null   object
#  22  created_at               2733 non-null   object
#  23  notes                    95 non-null     object
#  24  url                      2733 non-null   object
#  25  source                   2733 non-null   object
#  26  internal                 2733 non-null   bool
#  27  partisan                 79 non-null     object
#  28  race_id                  2733 non-null   int64
#  29  cycle                    2733 non-null   int64
#  30  office_type              2733 non-null   object
#  31  seat_number              0 non-null      float64
#  32  seat_name                2733 non-null   object
#  33  election_date            2733 non-null   object
#  34  stage                    2733 non-null   object
#  35  nationwide_batch         2733 non-null   bool
#  36  dem                      2733 non-null   float64
#  37  rep                      2733 non-null   float64
#  38  ind                      1233 non-null   float64
# dtypes: bool(2), datetime64[ns](2), float64(10), int64(6), object(19)
# memory usage: 795.5+ KB

# %%
gen_ballot_20 = gen_ballot[ gen_ballot['cycle'] == 2020]

# %%
gen_ballot_18 = gen_ballot[ gen_ballot['cycle'] == 2018]

# %%
gen_ballot_20 = gen_ballot_20[gen_ballot_20['end_date'] > dt.datetime(2020,10, 1) ]
gen_ballot_18 = gen_ballot_18[gen_ballot_18['end_date'] > dt.datetime(2018,10, 1) ]

# %%
gen_ballot_18
# Out:
#       poll_id  pollster_id                  pollster sponsor_ids  \
# 943     56856          241                     Ipsos          71
# 944     56856          241                     Ipsos          71
# 945     56857          241                     Ipsos          71
# 946     56857          241                     Ipsos          71
# 947     56857          241                     Ipsos          71
# ...       ...          ...                       ...         ...
# 1168    66580          552                   Winston        1312
# 1169    56092          241                     Ipsos          71
# 1170    56092          241                     Ipsos          71
# 1171    56092          241                     Ipsos          71
# 1172    56290          800  Kaiser Family Foundation         NaN
#
#                 sponsors              display_name  pollster_rating_id  \
# 943              Reuters                     Ipsos                 154
# 944              Reuters                     Ipsos                 154
# 945              Reuters                     Ipsos                 154
# 946              Reuters                     Ipsos                 154
# 947              Reuters                     Ipsos                 154
# ...                  ...                       ...                 ...
# 1168  Winning the Issues         The Winston Group                 385
# 1169             Reuters                     Ipsos                 154
# 1170             Reuters                     Ipsos                 154
# 1171             Reuters                     Ipsos                 154
# 1172                 NaN  Kaiser Family Foundation                 419
#
#           pollster_rating_name fte_grade methodology  state start_date  \
# 943                      Ipsos        B-      Online    NaN 2018-11-06
# 944                      Ipsos        B-      Online    NaN 2018-11-06
# 945                      Ipsos        B-      Online    NaN 2018-11-05
# 946                      Ipsos        B-      Online    NaN 2018-11-05
# 947                      Ipsos        B-      Online    NaN 2018-11-05
# ...                        ...       ...         ...    ...        ...
# 1168         The Winston Group       A/B      Online    NaN 2018-09-30
# 1169                     Ipsos        B-      Online    NaN 2018-09-26
# 1170                     Ipsos        B-      Online    NaN 2018-09-26
# 1171                     Ipsos        B-      Online    NaN 2018-09-26
# 1172  Kaiser Family Foundation       NaN  Live Phone    NaN 2018-09-19
#
#        end_date  sponsor_candidate_id  sponsor_candidate  \
# 943  2018-11-12                   NaN                NaN
# 944  2018-11-12                   NaN                NaN
# 945  2018-11-11                   NaN                NaN
# 946  2018-11-11                   NaN                NaN
# 947  2018-11-11                   NaN                NaN
# ...         ...                   ...                ...
# 1168 2018-10-02                   NaN                NaN
# 1169 2018-10-02                   NaN                NaN
# 1170 2018-10-02                   NaN                NaN
# 1171 2018-10-02                   NaN                NaN
# 1172 2018-10-02                   NaN                NaN
#
#       sponsor_candidate_party  question_id  sample_size population  \
# 943                       NaN        91721        649.0          a
# 944                       NaN        91727        531.0         rv
# 945                       NaN        91716        359.0         lv
# 946                       NaN        91722        968.0          a
# 947                       NaN        91728        801.0         rv
# ...                       ...          ...          ...        ...
# 1168                      NaN       124114       1000.0         rv
# 1169                      NaN        90003       1840.0         lv
# 1170                      NaN        90010       3316.0          a
# 1171                      NaN        90017       2707.0         rv
# 1172                      NaN        90480        949.0         rv
#
#       subpopulation population_full tracking      created_at  \
# 943             NaN               a     True  11/13/18 16:39
# 944             NaN              rv     True  11/13/18 16:40
# 945             NaN              lv     True  11/13/18 16:39
# 946             NaN               a     True  11/13/18 16:39
# 947             NaN              rv     True  11/13/18 16:40
# ...             ...             ...      ...             ...
# 1168            NaN              rv      NaN   5/29/20 13:11
# 1169            NaN              lv     True   10/9/18 16:24
# 1170            NaN               a     True   10/9/18 16:24
# 1171            NaN              rv     True   10/9/18 16:24
# 1172            NaN              rv      NaN  10/18/18 11:32
#
#                                                   notes  \
# 943                                                 NaN
# 944                                                 NaN
# 945                                                 NaN
# 946                                                 NaN
# 947                                                 NaN
# ...                                                 ...
# 1168                                                NaN
# 1169                                                NaN
# 1170                                                NaN
# 1171                                                NaN
# 1172  A bit confused on what the date ranges here sh...
#
#                                                     url   source  internal  \
# 943   http://polling.reuters.com/#!response/TM1212Y1...  Reuters     False
# 944   http://polling.reuters.com/#!response/TM1212Y1...  Reuters     False
# 945   http://polling.reuters.com/#!response/TM1212Y1...  Reuters     False
# 946   http://polling.reuters.com/#!response/TM1212Y1...  Reuters     False
# 947   http://polling.reuters.com/#!response/TM1212Y1...  Reuters     False
# ...                                                 ...      ...       ...
# 1168  https://www.winningtheissues.org/wp-content/up...      538     False
# 1169  http://polling.reuters.com/#!response/TM1212Y1...  Reuters     False
# 1170  http://polling.reuters.com/#!response/TM1212Y1...  Reuters     False
# 1171  http://polling.reuters.com/#!response/TM1212Y1...  Reuters     False
# 1172  http://files.kff.org/attachment/Topline-KFF-El...      538     False
#
#      partisan  race_id  cycle office_type  seat_number seat_name  \
# 943       NaN     8273   2018  U.S. House          NaN   Generic
# 944       NaN     8273   2018  U.S. House          NaN   Generic
# 945       NaN     8273   2018  U.S. House          NaN   Generic
# 946       NaN     8273   2018  U.S. House          NaN   Generic
# 947       NaN     8273   2018  U.S. House          NaN   Generic
# ...       ...      ...    ...         ...          ...       ...
# 1168      REP     8273   2018  U.S. House          NaN   Generic
# 1169      NaN     8273   2018  U.S. House          NaN   Generic
# 1170      NaN     8273   2018  U.S. House          NaN   Generic
# 1171      NaN     8273   2018  U.S. House          NaN   Generic
# 1172      NaN     8273   2018  U.S. House          NaN   Generic
#
#      election_date    stage  nationwide_batch   dem   rep  ind
# 943        11/6/18  general             False  42.4  31.2  1.6
# 944        11/6/18  general             False  48.9  35.7  1.6
# 945        11/6/18  general             False  46.0  45.0  3.1
# 946        11/6/18  general             False  41.3  32.7  2.2
# 947        11/6/18  general             False  47.3  37.2  2.1
# ...            ...      ...               ...   ...   ...  ...
# 1168       11/6/18  general             False  47.0  44.0  NaN
# 1169       11/6/18  general             False  50.5  37.7  3.8
# 1170       11/6/18  general             False  39.0  30.1  3.7
# 1171       11/6/18  general             False  44.7  34.6  4.3
# 1172       11/6/18  general             False  50.0  38.0  NaN
#
# [230 rows x 39 columns]

# %%
# !ls
# Out:
# 1976-2020-senate.csv		     initial-data-explore.ipynb
# cleaned_data			     president_approval_polls.csv
# codebook-us-senate-1976тАУ2020.md    president_approval_polls_historical.csv
# generic_ballot_polls.csv	     README.md
# generic_ballot_polls_historical.csv  senate_polls_historical.csv

# %%
senate_elections_18 = senate_elections[senate_elections['year'] == 2018].copy()

# %%
senate_elections_18['perc'] = senate_elections_18['candidatevotes'] / senate_elections_18['totalvotes']

# %%
senate_elections_18 = senate_elections_18[senate_elections_18['perc'] > .16]

# %%
senate_elections_18['party_simplified'] = senate_elections_18['party_simplified'].str.replace('OTHER','DEMOCRAT')

# %%
results_18_clean = senate_elections_18[['state','party_simplified','perc']].pivot_table(index='state', columns=['party_simplified'])

# %%
results_18_clean = results_18_clean.reset_index(level=0)

# %%
results_18_clean.columns = ['state','democrat','republican']

# %%
results_18_clean
# Out:
#             state  democrat  republican
# 0         ARIZONA  0.499558    0.476113
# 1      CALIFORNIA  0.500000         NaN
# 2     CONNECTICUT  0.567971    0.393497
# 3        DELAWARE  0.599531    0.378185
# 4         FLORIDA  0.499325    0.500550
# 5          HAWAII  0.711511    0.288489
# 6         INDIANA  0.448422    0.507324
# 7           MAINE  0.543143    0.352300
# 8        MARYLAND  0.648559    0.303065
# 9   MASSACHUSETTS  0.603368    0.361721
# 10       MICHIGAN  0.522619    0.457563
# 11      MINNESOTA  0.566403    0.392827
# 12    MISSISSIPPI  0.429207    0.560631
# 13       MISSOURI  0.455693    0.513832
# 14        MONTANA  0.503339    0.467824
# 15       NEBRASKA  0.386212    0.576850
# 16         NEVADA  0.504120    0.453850
# 17     NEW JERSEY  0.540071    0.428281
# 18     NEW MEXICO  0.540877    0.305322
# 19       NEW YORK  0.620214    0.285780
# 20   NORTH DAKOTA  0.442684    0.551055
# 21           OHIO  0.534114    0.465656
# 22   PENNSYLVANIA  0.556132    0.427428
# 23   RHODE ISLAND  0.614424    0.383346
# 24      TENNESSEE  0.439200    0.547070
# 25          TEXAS  0.483254    0.508926
# 26           UTAH  0.309115    0.625881
# 27        VERMONT  0.673195    0.273868
# 28       VIRGINIA  0.570026    0.410075
# 29     WASHINGTON  0.584338    0.415662
# 30  WEST VIRGINIA  0.495458    0.462973
# 31      WISCONSIN  0.554177    0.445807
# 32        WYOMING  0.300988    0.669600

# %%
results_18_clean = results_18_clean[results_18_clean['state'] != 'CALIFORNIA']

# %%
results_18_clean['partisan-score'] = results_18_clean['democrat'] - results_18_clean['republican']
# Out:
# /tmp/ipykernel_263250/3391485717.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_18_clean['partisan-score'] = results_18_clean['democrat'] - results_18_clean['republican']

# %% [markdown]
# I think we will start the historic data in 2008 (so we will cover Obama, Trump, and Biden eras). Now I want to get all the partisan scores in one dataframe.

# %%
def get_score(year):
    year_data = senate_elections[senate_elections['year'] == year].copy()
    #as the independent senators in the 2010s caucused with the dems, we will count them as democrats: 
    year_data['party_simplified'] = year_data['party_simplified'].str.replace('OTHER','DEMOCRAT')
    year_data['perc'] = year_data['candidatevotes'] / year_data['totalvotes']
    year_data = year_data[year_data['perc'] > .1]
    results_clean = year_data[['state','party_simplified','perc']].pivot_table(index='state', columns=['party_simplified'])
    results_clean = results_clean.reset_index(level=0)
    if len(results_clean.columns) == 4:
        results_clean.columns = ['state','democrat','other','republican']
    if len(results_clean.columns) == 3:
        results_clean.columns = ['state','democrat','republican']
    #Below, we drop CA because the single primary often results in two dems running against each other in the general.
    results_clean = results_clean[results_clean['state'] != 'CALIFORNIA']
    results_clean['partisan_score_{}'.format(year)] = results_clean['democrat'] - results_clean['republican']
    return results_clean[['state','partisan_score_{}'.format(year)]]

# %%
def get_score_detail(year):
    year_data = senate_elections[senate_elections['year'] == year].copy()
    #as the independent senators in the 2010s caucused with the dems, we will count them as democrats: 
    year_data['party_simplified'] = year_data['party_simplified'].str.replace('OTHER','DEMOCRAT')
    year_data['perc'] = year_data['candidatevotes'] / year_data['totalvotes']
    year_data = year_data[year_data['perc'] > .1]
    results_clean = year_data[['state','party_simplified','perc']].pivot_table(index='state', columns=['party_simplified'])
    results_clean = results_clean.reset_index(level=0)
    if len(results_clean.columns) == 4:
        results_clean.columns = ['state','democrat','other','republican']
    if len(results_clean.columns) == 3:
        results_clean.columns = ['state','democrat','republican']
    #Below, we drop CA because the single primary often results in two dems running against each other in the general.
    results_clean = results_clean[results_clean['state'] != 'CALIFORNIA']
    results_clean['partisan_score_{}'.format(year)] = results_clean['democrat'] - results_clean['republican']
    return results_clean

# %%
results = get_score(2020)

# %%
for year in [2018, 2016, 2014, 2012, 2010, 2008]:
    results = results.merge(get_score(year), how='outer', on='state')

# %% [markdown]
# I think I will try to train the model to predict 2020, and add in some more info maybe

# %%
gen_ballot_20['partisan_lean'] = gen_ballot_20['dem'] - gen_ballot_20['rep']

# %%
gen_ballot_20['partisan_lean'].mean()
# Out:
# 7.464466019417477

# %%
gen_ballot_20[gen_ballot_20['end_date'] > dt.datetime(2020,10,25)]['partisan_lean'].mean()
# Out:
# 7.672121212121212

# %%
results.insert(loc=2, column='avg_score_bef_2020', value=results[['partisan_score_2018', 'partisan_score_2016']].mean(axis=1))

# %%
results['partisan_score_2020'][results['state'] == 'GEORGIA'] = np.NaN
# Out:
# /tmp/ipykernel_263250/2670611353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['partisan_score_2020'][results['state'] == 'GEORGIA'] = np.NaN

# %%
results.insert(loc=2, column='predicted_partisan_score', value=results['avg_score_bef_2020'] + .0767)

# %%
results.insert(loc=2, column='prediction_error', value=abs(results['partisan_score_2020'] - results['predicted_partisan_score']))

# %%
results.head(10)
# Out:
#       state  partisan_score_2020  prediction_error  predicted_partisan_score  \
# 0   ALABAMA            -0.203587          0.000628                 -0.204215
# 1    ALASKA            -0.127032          0.115596                 -0.242629
# 2   ARIZONA             0.023487          0.000128                  0.023615
# 3  ARKANSAS                  NaN               NaN                 -0.159306
# 4  COLORADO             0.093214          0.040136                  0.133350
# 5  DELAWARE             0.215405          0.082640                  0.298045
# 6   GEORGIA                  NaN               NaN                 -0.060806
# 7     IDAHO            -0.293759          0.013620                 -0.307379
# 8  ILLINOIS             0.160676          0.066837                  0.227513
# 9      IOWA            -0.064782          0.102865                 -0.167647
#
#    avg_score_bef_2020  partisan_score_2018  partisan_score_2016  \
# 0           -0.280915                  NaN            -0.280915
# 1           -0.319329                  NaN            -0.319329
# 2           -0.053085             0.023445            -0.129616
# 3           -0.236006                  NaN            -0.236006
# 4            0.056650                  NaN             0.056650
# 5            0.221345             0.221345                  NaN
# 6           -0.137506                  NaN            -0.137506
# 7           -0.384079                  NaN            -0.384079
# 8            0.150813                  NaN             0.150813
# 9           -0.244347                  NaN            -0.244347
#
#    partisan_score_2014  partisan_score_2012  partisan_score_2010  \
# 0                  NaN                  NaN            -0.304653
# 1            -0.021296                  NaN            -0.040199
# 2                  NaN            -0.030273            -0.242088
# 3            -0.170672                  NaN            -0.209578
# 4            -0.019445                  NaN             0.016283
# 5             0.136012             0.374657             0.165773
# 6            -0.076827                  NaN            -0.193087
# 7            -0.306567                  NaN            -0.462474
# 8             0.108537                  NaN            -0.015986
# 9            -0.083389                  NaN            -0.310492
#
#    partisan_score_2008
# 0            -0.268418
# 1             0.012442
# 2                  NaN
# 3                  NaN
# 4             0.103035
# 5             0.293730
# 6            -0.089013
# 7            -0.235493
# 8             0.393109
# 9             0.253945

# %%
results[['state','prediction_error']].sort_values(by='prediction_error')
# Out:
#              state  prediction_error
# 2          ARIZONA          0.000128
# 0          ALABAMA          0.000628
# 14   MASSACHUSETTS          0.004245
# 7            IDAHO          0.013620
# 26    RHODE ISLAND          0.023461
# 21      NEW JERSEY          0.025415
# 23  NORTH CAROLINA          0.037207
# 4         COLORADO          0.040136
# 17     MISSISSIPPI          0.045036
# 28    SOUTH DAKOTA          0.045152
# 24        OKLAHOMA          0.053317
# 8         ILLINOIS          0.066837
# 20   NEW HAMPSHIRE          0.078410
# 27  SOUTH CAROLINA          0.082595
# 5         DELAWARE          0.082640
# 9             IOWA          0.102865
# 10          KANSAS          0.108300
# 1           ALASKA          0.115596
# 31        VIRGINIA          0.115814
# 15        MICHIGAN          0.124906
# 11        KENTUCKY          0.126550
# 13           MAINE          0.133220
# 25          OREGON          0.133364
# 30           TEXAS          0.147422
# 16       MINNESOTA          0.197891
# 18         MONTANA          0.212458
# 29       TENNESSEE          0.239201
# 22      NEW MEXICO          0.251203
# 19        NEBRASKA          0.269192
# 12       LOUISIANA          0.493464
# 32   WEST VIRGINIA          0.542023
# 3         ARKANSAS               NaN
# 6          GEORGIA               NaN
# 33         WYOMING               NaN
# 34     CONNECTICUT               NaN
# 35         FLORIDA               NaN
# 36          HAWAII               NaN
# 37         INDIANA               NaN
# 38        MARYLAND               NaN
# 39        MISSOURI               NaN
# 40          NEVADA               NaN
# 41        NEW YORK               NaN
# 42    NORTH DAKOTA               NaN
# 43            OHIO               NaN
# 44    PENNSYLVANIA               NaN
# 45            UTAH               NaN
# 46         VERMONT               NaN
# 47      WASHINGTON               NaN
# 48       WISCONSIN               NaN

# %%
results['prediction_error'].mean()
# Out:
# 0.1262029962046844

# %%
results.insert(loc=2, column='predicted_partisan_score_14', value=results['partisan_score_2014'] + .0767)

# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48                  NaN

# %%
small_results = senate_elections[(senate_elections['special'] == False) & (senate_elections['year'] >= 2008)]

# %%
small_results = small_results[ small_results['state'] != 'CALIFORNIA']

# %% [markdown]
# 2014, 2016, 2018, 2020 results as the outcome variables.

# %%
small_results.head()
# Out:
#       year    state state_po  state_fips  state_cen  state_ic     office  \
# 2284  2008  ALABAMA       AL           1         63        41  US SENATE
# 2285  2008  ALABAMA       AL           1         63        41  US SENATE
# 2286  2008  ALABAMA       AL           1         63        41  US SENATE
# 2287  2008   ALASKA       AK           2         94        81  US SENATE
# 2288  2008   ALASKA       AK           2         94        81  US SENATE
#
#        district stage  special             candidate party_detailed  writein  \
# 2284  statewide   gen    False  VIVIAN DAVIS FIGURES       DEMOCRAT    False
# 2285  statewide   gen    False                   NaN            NaN     True
# 2286  statewide   gen    False         JEFF SESSIONS     REPUBLICAN    False
# 2287  statewide   gen    False           TED STEVENS     REPUBLICAN    False
# 2288  statewide   gen    False                   NaN            NaN     True
#
#        mode  candidatevotes  totalvotes  unofficial   version party_simplified
# 2284  total          752391     2060191       False  20210114         DEMOCRAT
# 2285  total            2417     2060191       False  20210114            OTHER
# 2286  total         1305383     2060191       False  20210114       REPUBLICAN
# 2287  total          147814      317723       False  20210114       REPUBLICAN
# 2288  total            1077      317723       False  20210114            OTHER

# %%
r_18 = small_results[small_results['year'] == 2018].copy()
r_18['perc'] = r_18['candidatevotes'] / r_18['totalvotes']
r_18 = r_18[(r_18['perc'] > .2) & (r_18['perc'] < .8)]
r_18['party_simplified'] = r_18['party_simplified'].str.replace('OTHER', 'DEMOCRAT')
# r_18 = r_18[ (r_18['party_simplified'] == "DEMOCRAT") | (r_18['party_simplified'] == "REPUBLICAN")]

# %%
r_18.tail(32)
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 3348  2018     NEW JERSEY       NJ          34         22        12
# 3349  2018     NEW JERSEY       NJ          34         22        12
# 3356  2018     NEW MEXICO       NM          35         85        66
# 3358  2018     NEW MEXICO       NM          35         85        66
# 3359  2018       NEW YORK       NY          36         21        13
# 3360  2018       NEW YORK       NY          36         21        13
# 3366  2018   NORTH DAKOTA       ND          38         44        36
# 3367  2018   NORTH DAKOTA       ND          38         44        36
# 3369  2018           OHIO       OH          39         31        24
# 3371  2018           OHIO       OH          39         31        24
# 3372  2018   PENNSYLVANIA       PA          42         23        14
# 3373  2018   PENNSYLVANIA       PA          42         23        14
# 3376  2018   RHODE ISLAND       RI          44         15         5
# 3377  2018   RHODE ISLAND       RI          44         15         5
# 3379  2018      TENNESSEE       TN          47         62        54
# 3380  2018      TENNESSEE       TN          47         62        54
# 3387  2018          TEXAS       TX          48         74        49
# 3388  2018          TEXAS       TX          48         74        49
# 3390  2018           UTAH       UT          49         87        67
# 3391  2018           UTAH       UT          49         87        67
# 3401  2018        VERMONT       VT          50         13         6
# 3403  2018        VERMONT       VT          50         13         6
# 3405  2018       VIRGINIA       VA          51         54        40
# 3406  2018       VIRGINIA       VA          51         54        40
# 3409  2018     WASHINGTON       WA          53         91        73
# 3410  2018     WASHINGTON       WA          53         91        73
# 3411  2018  WEST VIRGINIA       WV          54         55        56
# 3412  2018  WEST VIRGINIA       WV          54         55        56
# 3414  2018      WISCONSIN       WI          55         35        25
# 3415  2018      WISCONSIN       WI          55         35        25
# 3417  2018        WYOMING       WY          56         83        68
# 3418  2018        WYOMING       WY          56         83        68
#
#          office   district stage  special                candidate  \
# 3348  US SENATE  statewide   gen    False          ROBERT MENENDEZ
# 3349  US SENATE  statewide   gen    False                BOB HUGIN
# 3356  US SENATE  statewide   gen    False        MARTIN T HEINRICH
# 3358  US SENATE  statewide   gen    False                MICK RICH
# 3359  US SENATE  statewide   gen    False    KIRSTEN E. GILLIBRAND
# 3360  US SENATE  statewide   gen    False   CHELE CHIAVACCI FARLEY
# 3366  US SENATE  statewide   gen    False             KEVIN CRAMER
# 3367  US SENATE  statewide   gen    False           HEIDI HEITKAMP
# 3369  US SENATE  statewide   gen    False            SHERROD BROWN
# 3371  US SENATE  statewide   gen    False              JIM RENACCI
# 3372  US SENATE  statewide   gen    False        ROBERT P CASEY JR
# 3373  US SENATE  statewide   gen    False        LOUIS J. BARLETTA
# 3376  US SENATE  statewide   gen    False       SHELDON WHITEHOUSE
# 3377  US SENATE  statewide   gen    False  ROBERT G. FLANDERS, JR.
# 3379  US SENATE  statewide   gen    False         MARSHA BLACKBURN
# 3380  US SENATE  statewide   gen    False            PHIL BREDESEN
# 3387  US SENATE  statewide   gen    False                 TED CRUZ
# 3388  US SENATE  statewide   gen    False            BETO O'ROURKE
# 3390  US SENATE  statewide   gen    False              MITT ROMNEY
# 3391  US SENATE  statewide   gen    False             JENNY WILSON
# 3401  US SENATE  statewide   gen    False           BERNIE SANDERS
# 3403  US SENATE  statewide   gen    False           LAWRENCE ZUPAN
# 3405  US SENATE  statewide   gen    False         COREY A. STEWART
# 3406  US SENATE  statewide   gen    False         TIMOTHY M. KAINE
# 3409  US SENATE  statewide   gen    False           MARIA CANTWELL
# 3410  US SENATE  statewide   gen    False          SUSAN HUTCHISON
# 3411  US SENATE  statewide   gen    False              JOE MANCHIN
# 3412  US SENATE  statewide   gen    False         PATRICK MORRISEY
# 3414  US SENATE  statewide   gen    False            TAMMY BALDWIN
# 3415  US SENATE  statewide   gen    False              LEAH VUKMIR
# 3417  US SENATE  statewide   gen    False            JOHN BARRASSO
# 3418  US SENATE  statewide   gen    False             GARY TRAUNER
#
#       party_detailed  writein   mode  candidatevotes  totalvotes  unofficial  \
# 3348        DEMOCRAT    False  total         1711654     3169310       False
# 3349      REPUBLICAN    False  total         1357355     3169310       False
# 3356        DEMOCRAT    False  total          376998      697012       False
# 3358      REPUBLICAN    False  total          212813      697012       False
# 3359        DEMOCRAT    False  total         3755489     6055151       False
# 3360      REPUBLICAN    False  total         1730439     6055151       False
# 3366      REPUBLICAN    False  total          179720      326138       False
# 3272  2018        ARIZONA       AZ           4         86        61
# 3277  2018    CONNECTICUT       CT           9         16         1
# 3278  2018    CONNECTICUT       CT           9         16         1
# 3279  2018    CONNECTICUT       CT           9         16         1
# ...    ...            ...      ...         ...        ...       ...
# 3408  2018       VIRGINIA       VA          51         54        40
# 3413  2018  WEST VIRGINIA       WV          54         55        56
# 3416  2018      WISCONSIN       WI          55         35        25
# 3419  2018        WYOMING       WY          56         83        68
# 3420  2018        WYOMING       WY          56         83        68
#
#          office   district stage  special             candidate  \
# 3271  US SENATE  statewide   gen    False          ANGELA GREEN
# 3272  US SENATE  statewide   gen    False                   NaN
# 3277  US SENATE  statewide   gen    False  CHRISTOPHER S MURPHY
# 3278  US SENATE  statewide   gen    False          RICHARD LION
# 3279  US SENATE  statewide   gen    False          JEFF RUSSELL
# ...         ...        ...   ...      ...                   ...
# 3408  US SENATE  statewide   gen    False                   NaN
# 3413  US SENATE  statewide   gen    False          RUSTY HOLLEN
# 3416  US SENATE  statewide   gen    False                   NaN
# 3419  US SENATE  statewide   gen    False        JOSEPH PORAMBO
# 3420  US SENATE  statewide   gen    False                   NaN
#
#         party_detailed  writein   mode  candidatevotes  totalvotes  \
# 3271             GREEN    False  total           57442     2384308
# 3272               NaN     True  total             566     2384308
# 3277  WORKING FAMILIES    False  total           37894     1386840
# 3278       LIBERTARIAN    False  total            8838     1386840
# 3279             GREEN    False  total            6618     1386840
# ...                ...      ...    ...             ...         ...
# 3408               NaN     True  total            5125     3351373
# 3413       LIBERTARIAN    False  total           24231      582911
# 3416               NaN     True  total              42     2657841
# 3419       LIBERTARIAN    False  total            5658      203420
# 3420               NaN     True  total             325      203420
#
#       unofficial   version party_simplified      perc
# 3271       False  20210114            OTHER  0.024092
# 3272       False  20210114            OTHER  0.000237
# 3277       False  20210114            OTHER  0.027324
# 3278       False  20210114      LIBERTARIAN  0.006373
# 3279       False  20210114            OTHER  0.004772
# ...          ...       ...              ...       ...
# 3408       False  20210114            OTHER  0.001529
# 3413        True  20210114      LIBERTARIAN  0.041569
# 3416       False  20210114            OTHER  0.000016
# 3419       False  20210114      LIBERTARIAN  0.027814
# 3420       False  20210114            OTHER  0.001598
#
# [79 rows x 20 columns]

# %%
sum((r_18['perc'] < .2) | (r_18['perc'] > .8))
# Out:
# 1

# %%
states_to_drop = []
for state in r_18['state'].unique():
    state_rows = r_18[r_18['state'] == state]
    if sum((state_rows['perc'] < .2) | (state_rows['perc'] > .8)) != 0:
        states_to_drop.append(state)

# %%
states_to_drop
# Out:
# ['MAINE']

# %%
for state in states_to_drop:
    r_18 = r_18[r_18['state'] != state]

# %%
# def get_results_nice(year):
#     year_data = small_results[small_results['year'] == 2018].copy()
#     year_data['perc'] = year_data['candidatevotes'] / year_data['totalvotes']
#     year_data = year_data[ (year_data['party_simplified'] == "DEMOCRAT") | (year_data['party_simplified'] == "REPUBLICAN")]
#     states_to_drop = []
#     for state in year_data['state'].unique():
#         state_rows = year_data[year_data['state'] == state]
#         if sum((state_rows['perc'] < .2) | (state_rows['perc'] > .8)) != 0:
#             states_to_drop.append(state)
#     for state in states_to_drop:
#         year_data = year_data[year_data['state'] != state]
#     return year_data

# %%
def get_single_year(year):
    year_data = small_results[small_results['year'] == year].copy()
    year_data['perc'] = year_data['candidatevotes'] / year_data['totalvotes']
    year_data = year_data[(year_data['perc'] > .2) & (year_data['perc'] < .8)]
    year_data['party_simplified'] = year_data['party_simplified'].str.replace('OTHER', 'DEMOCRAT')
    year_data = year_data[['state','party_simplified','perc']].pivot_table(index='state', columns=['party_simplified'])
    year_data = year_data.reset_index(level=0)
    if len(year_data.columns) == 4:
        year_data.columns = ['state','democrat','other','republican']
    if len(year_data.columns) == 3:
        year_data.columns = ['state','democrat','republican']    
    year_data['partisan_score_{}'.format(year)] = year_data['democrat'] - year_data['republican']
    return year_data[['state','partisan_score_{}'.format(year)]]

# %%
def create_3_past(year):
    current_year = get_single_year(year)
    two_ago = get_single_year(year - 2)
    four_ago = get_single_year(year - 4)
    six_ago = get_single_year(year - 6)
    current_year = current_year.merge(two_ago, how='outer', on='state')
    current_year = current_year.merge(four_ago, how='outer', on='state')
    current_year = current_year.merge(six_ago, how='outer', on='state')
    current_year.columns = ['state', 'partisan_score', 'two_ago_score', 'four_ago_score', 'six_ago_score']
    return current_year

# %%
def average_3_past(year):
    df = create_3_past(year)
    df['old_score_avg'] = df[['two_ago_score', 'four_ago_score', 'six_ago_score']].mean(axis=1)
    df = df[['state','partisan_score','old_score_avg']]
    df.dropna(inplace=True)
    return df[['state','partisan_score','old_score_avg']]

# %%
average_3_past(2020)
# Out:
#              state  partisan_score  old_score_avg
# 0          ALABAMA       -0.203587      -0.280915
# 1           ALASKA       -0.127032      -0.021296
# 3         COLORADO        0.093214       0.018603
# 4         DELAWARE        0.215405       0.178679
# 5          GEORGIA       -0.017790      -0.107166
# 6            IDAHO       -0.293759      -0.345323
# 7         ILLINOIS        0.160676       0.129675
# 8             IOWA       -0.064782      -0.163868
# 9           KANSAS       -0.114371      -0.202779
# 10        KENTUCKY       -0.195338      -0.150080
# 12           MAINE       -0.085019      -0.085496
# 13   MASSACHUSETTS        0.322592       0.234688
# 14        MICHIGAN        0.016850       0.098955
# 15       MINNESOTA        0.052384       0.171696
# 16     MISSISSIPPI       -0.099759      -0.205118
# 17         MONTANA       -0.100243      -0.070832
# 18        NEBRASKA       -0.383131      -0.259577
# 19   NEW HAMPSHIRE        0.156485       0.016909
# 20      NEW JERSEY        0.163075       0.123444
# 21      NEW MEXICO        0.061053       0.173366
# 22  NORTH CAROLINA       -0.017467      -0.036303
# 23        OKLAHOMA       -0.301586      -0.413100
# 24          OREGON        0.175868       0.210576
# 25    RHODE ISLAND        0.331239       0.322216
# 26  SOUTH CAROLINA       -0.102703      -0.218177
# 27    SOUTH DAKOTA       -0.314705      -0.322578
# 28       TENNESSEE       -0.270371      -0.203942
# 29           TEXAS       -0.096394      -0.148814
# 30        VIRGINIA        0.120838       0.084033
# 31   WEST VIRGINIA       -0.432838      -0.122024
